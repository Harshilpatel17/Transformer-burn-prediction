# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data1=pd.read_excel("/content/drive/MyDrive/Harshil_Project/Dataset_Year_2019.xlsx")

# %%
data2=pd.read_excel("/content/drive/MyDrive/Harshil_Project/Dataset_Year_2020.xlsx")

# %%
data1.describe()
# Out:
#            LOCATION         POWER  SELF-PROTECTION  \
# count  15873.000000  15873.000000     15873.000000
# mean       0.173943     27.272570         0.100044
# std        0.379073     35.655785         0.300068
# min        0.000000      5.000000         0.000000
# 25%        0.000000     10.000000         0.000000
# 50%        0.000000     15.000000         0.000000
# 75%        0.000000     30.000000         0.000000
# max        1.000000   2000.000000         1.000000
#
#        Average earth discharge density DDT [Rays/km^2-año]  \
# count                                       15873.000000
# mean                                            2.230378
# std                                             1.745835
# min                                             0.000000
# 25%                                             0.888588
# 50%                                             1.351333
# 75%                                             3.155602
# ...

# %%
a=data1[data1['Burned transformers 2019']==1]
a
# Out:
#        LOCATION  POWER  SELF-PROTECTION  \
# 10            1  112.5                0
# 61            1  112.5                0
# 264           1   10.0                0
# 282           1   75.0                0
# 348           1   75.0                1
# ...         ...    ...              ...
# 15835         0   15.0                1
# 15838         0   10.0                0
# 15853         0    5.0                1
# 15854         0   10.0                0
# 15858         0   15.0                1
#
#        Average earth discharge density DDT [Rays/km^2-año]  \
# 10                                              3.155602
# 61                                              3.155602
# 264                                             3.155602
# 282                                             3.155602
# 348                                             3.155602
# ...                                                  ...
# 15835                                           3.155602
# ...

# %%
data1.rename(columns = {'Burned transformers 2019':'Burned transformers'}, inplace = True)
data2.rename(columns = {'Burned transformers 2020':'Burned transformers'}, inplace = True)

# %%
merged_data=pd.concat([data1,data2],axis=0)

# %%
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31746 entries, 0 to 15872
# Data columns (total 16 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   LOCATION                                                    31746 non-null  int64
#  1   POWER                                                       31746 non-null  float64
#  2   SELF-PROTECTION                                             31746 non-null  int64
#  3   Average earth discharge density DDT [Rays/km^2-año]         31746 non-null  float64
#  4   Maximum ground discharge density DDT [Rays/km^2-año]        31746 non-null  float64
#  5   Burning rate  [Failures/year]                               31746 non-null  float64
#  6   Criticality according to previous study for ceramics level  31746 non-null  int64
# ...

# %%
merged_data['Type of clients'].value_counts()
# Out:
# STRATUM 1     26740
# STRATUM 2      2240
# STRATUM 3       854
# COMMERCIAL      676
# STRATUM 4       654
# INDUSTRIAL      238
# STRATUM 5       176
# OFFICIAL        132
# STRATUM 6        36
# Name: Type of clients, dtype: int64

# %%
merged_data['Type of installation'].value_counts()
# Out:
# POLE                            25488
# MACRO WITHOUT ANTI-FRAUD NET     3262
# POLE WITH ANTI-FRAUD NET         1047
# POLE WITH ANTI-FRAU NET          1047
# EN H                              718
# OTROS                             112
# PAD MOUNTED                        64
# TORRE METALICA                      6
# CABINA                              2
# Name: Type of installation, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
sns.set(style="whitegrid")  # Set the style of the plot

# Create a count plot
plt.figure(figsize=(15, 6))  # Set the size of the plot
sns.countplot(x="Type of clients", data=merged_data)

# Set plot labels and title
plt.xlabel("Type of Clients")
plt.ylabel("Count")
plt.title("Count Plot for Type of Clients")

# Show the plot
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Assuming your DataFrame is named df
sns.set(style="whitegrid")  # Set the style of the plot

# Create a count plot
plt.figure(figsize=(8, 5))  # Set the size of the plot
sns.countplot(x="Removable connectors", data=merged_data)
plt.xticks(ticks=[0, 1], labels=["No Removable Connectors", "Removable Connectors"])
# Set plot labels and title
plt.xlabel("Removable Connectors")
plt.ylabel("Count")
plt.title("Count Plot for Removable Connectors")

# Show the plot
plt.show()

# %%
fig, ax = plt.subplots(figsize=(24,12))
sns.heatmap(merged_data.corr(),annot=True,linewidths=.5)
# Out:
# <ipython-input-14-85cead04d7c0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(merged_data.corr(),annot=True,linewidths=.5)
# <Axes: >

# %%
from sklearn.preprocessing import LabelEncoder
enc=LabelEncoder()
for i in merged_data.columns:
    if merged_data[i].dtype=='object':
        merged_data[i]=enc.fit_transform(merged_data[i])
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31746 entries, 0 to 15872
# Data columns (total 16 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   LOCATION                                                    31746 non-null  int64
#  1   POWER                                                       31746 non-null  float64
#  2   SELF-PROTECTION                                             31746 non-null  int64
#  3   Average earth discharge density DDT [Rays/km^2-año]         31746 non-null  float64
#  4   Maximum ground discharge density DDT [Rays/km^2-año]        31746 non-null  float64
#  5   Burning rate  [Failures/year]                               31746 non-null  float64
#  6   Criticality according to previous study for ceramics level  31746 non-null  int64
# ...

# %%
merged_data['Type of clients'].value_counts()
# Out:
# 3    26740
# 4     2240
# 5      854
# 0      676
# 6      654
# 1      238
# 7      176
# 2      132
# 8       36
# Name: Type of clients, dtype: int64

# %%
merged_data['Type of installation'].value_counts()
# Out:
# 5    25488
# 2     3262
# 7     1047
# 6     1047
# 1      718
# 3      112
# 4       64
# 8        6
# 0        2
# Name: Type of installation, dtype: int64

# %%
merged_data.drop_duplicates()
merged_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 31746 entries, 0 to 15872
# Data columns (total 16 columns):
#  #   Column                                                      Non-Null Count  Dtype
# ---  ------                                                      --------------  -----
#  0   LOCATION                                                    31746 non-null  int64
#  1   POWER                                                       31746 non-null  float64
#  2   SELF-PROTECTION                                             31746 non-null  int64
#  3   Average earth discharge density DDT [Rays/km^2-año]         31746 non-null  float64
#  4   Maximum ground discharge density DDT [Rays/km^2-año]        31746 non-null  float64
#  5   Burning rate  [Failures/year]                               31746 non-null  float64
#  6   Criticality according to previous study for ceramics level  31746 non-null  int64
# ...

# %%
merged_data.describe()
# Out:
#            LOCATION         POWER  SELF-PROTECTION  \
# count  31746.000000  31746.000000     31746.000000
# mean       0.173943     27.272570         0.100044
# std        0.379067     35.655223         0.300064
# min        0.000000      5.000000         0.000000
# 25%        0.000000     10.000000         0.000000
# 50%        0.000000     15.000000         0.000000
# 75%        0.000000     30.000000         0.000000
# max        1.000000   2000.000000         1.000000
#
#        Average earth discharge density DDT [Rays/km^2-año]  \
# count                                       31746.000000
# mean                                            2.230378
# std                                             1.745807
# min                                             0.000000
# 25%                                             0.888588
# 50%                                             1.351333
# 75%                                             3.155602
# ...

# %%
merged_data
# Out:
#        LOCATION  POWER  SELF-PROTECTION  \
# 0             1  112.5                0
# 1             1   10.0                0
# 2             1   25.0                0
# 3             1   75.0                0
# 4             1   75.0                0
# ...         ...    ...              ...
# 15868         0   37.5                0
# 15869         0   37.5                0
# 15870         0   25.0                0
# 15871         0   10.0                0
# 15872         0   15.0                0
#
#        Average earth discharge density DDT [Rays/km^2-año]  \
# 0                                               3.155602
# 1                                               3.155602
# 2                                               3.155602
# 3                                               3.155602
# 4                                               3.155602
# ...                                                  ...
# 15868                                           3.155602
# ...

# %%
y=merged_data['Burned transformers']
x=merged_data.drop(['Burned transformers'],axis=1)

# %%
x
# Out:
#        LOCATION  POWER  SELF-PROTECTION  \
# 0             1  112.5                0
# 1             1   10.0                0
# 2             1   25.0                0
# 3             1   75.0                0
# 4             1   75.0                0
# ...         ...    ...              ...
# 15868         0   37.5                0
# 15869         0   37.5                0
# 15870         0   25.0                0
# 15871         0   10.0                0
# 15872         0   15.0                0
#
#        Average earth discharge density DDT [Rays/km^2-año]  \
# 0                                               3.155602
# 1                                               3.155602
# 2                                               3.155602
# 3                                               3.155602
# 4                                               3.155602
# ...                                                  ...
# 15868                                           3.155602
# ...

# %%
from sklearn.preprocessing import StandardScaler

# Assuming you have your data stored in a variable named 'x'
std = StandardScaler()
x = std.fit_transform(x)

# %%
x
# Out:
# array([[ 2.17922096,  2.39035869, -0.33341499, ...,  0.04564355,
#         -0.89116077, -0.5732458 ],
#        [ 2.17922096, -0.48444071, -0.33341499, ...,  0.04564355,
#         -0.89116077, -0.57324611],
#        [ 2.17922096, -0.06373836, -0.33341499, ...,  0.04564355,
#         -0.89116077, -0.57324616],
#        ...,
#        [-0.45887958, -0.06373836, -0.33341499, ...,  0.04564355,
#          1.12213198, -0.57324013],
#        [-0.45887958, -0.48444071, -0.33341499, ...,  0.04564355,
#         -0.89116077,  1.83229858],
#        [-0.45887958, -0.3442066 , -0.33341499, ...,  0.04564355,
#          1.12213198, -0.57323858]])

# %% [markdown]
# # Clustering before classification

# %%
merged_data.columns
# Out:
# Index(['LOCATION', 'POWER', 'SELF-PROTECTION',
#        'Average earth discharge density DDT [Rays/km^2-año]',
#        'Maximum ground discharge density DDT [Rays/km^2-año]',
#        'Burning rate  [Failures/year]',
#        'Criticality according to previous study for ceramics level',
#        'Removable connectors', 'Type of clients', 'Number of users',
#        'Electric power not supplied EENS [kWh] ', 'Type of installation',
#        'Air network', 'Circuit Queue', 'km of network LT:',
#        'Burned transformers'],
#       dtype='object')

# %%
from sklearn.cluster import *
from sklearn.model_selection import train_test_split

# Implement clustering
kmeans = KMeans(n_clusters=2,algorithm='elkan')
kmeans.fit(x)
a=kmeans.labels_
# Get the cluster labels
cluster_labels = kmeans.predict(x)

merged_data['clustered labels']=cluster_labels
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
from sklearn.metrics import silhouette_score,calinski_harabasz_score,davies_bouldin_score, rand_score, adjusted_rand_score, adjusted_mutual_info_score,v_measure_score,fowlkes_mallows_score
print('rand',rand_score(a,y))
print('fowlkes mallows score',fowlkes_mallows_score(a,y))
print('silhouette',silhouette_score(x,a))
print('davies',davies_bouldin_score(x,a))
print('calinski',calinski_harabasz_score(x,a))
# Out:
# rand 0.6728867385978742
# fowlkes mallows score 0.8057981512356004
# silhouette 0.32194606127200404
# davies 1.52905719132375
# calinski 6441.21445930235

# %%
import pickle
pickle.dump(kmeans, open('clustering model.pkl', 'wb'))

# %%
merged_data.columns=['LOCATION', 'POWER', 'SELF PROTECTION',
       'Average earth discharge density DDT',
       'Maximum ground discharge density DDT',
       'Burning rate',
       'Criticality according to previous study for ceramics level',
       'Removable connectors', 'Type of clients', 'Number of users',
       'Electric power not supplied EENS', 'Type of installation',
       'Air network', 'Circuit Queue', 'km of network LT',
       'Burned transformers', 'clustered labels']
y_c=merged_data['clustered labels']
x=merged_data.drop(['clustered labels','Burned transformers'],axis=1)

# %%
from sklearn.preprocessing import StandardScaler

std = StandardScaler()

std.fit(x)

x = std.transform(x)

mean = std.mean_
scale = std.scale_

print(f"Mean: {mean}")
print(f"Standard Deviation: {scale}")
# Out:
# Mean: [1.73943174e-01 2.72725698e+01 1.00044100e-01 2.23037837e+00
#  5.66785737e+00 8.02195552e-02 2.19240219e-01 4.86297486e-01
#  3.13097713e+00 2.42073962e+01 5.46705986e+02 4.69139419e+00
#  9.97920998e-01 4.42638443e-01 4.21100987e+04]
# Standard Deviation: [3.79060610e-01 3.56546616e+01 3.00058791e-01 1.74577953e+00
#  3.54210057e+00 1.64329167e-01 4.13731731e-01 4.99812206e-01
#  8.30219668e-01 3.17912072e+01 8.01946907e+02 1.17291066e+00
#  4.55486534e-02 4.96698754e-01 7.34584978e+04]

# %%
Mean = []
for i in range(len(mean)):
  Mean.append(mean[i])
Mean
# Out:
# [0.17394317394317393,
#  27.272569772569774,
#  0.10004410004410004,
#  2.230378365677752,
#  5.667857367857367,
#  0.08021955521955522,
#  0.21924021924021925,
#  0.4862974862974863,
#  3.130977130977131,
#  24.207396207396208,
#  546.7059860139859,
#  4.691394191394191,
#  0.997920997920998,
#  0.44263844263844265,
#  42110.09874531658]

# %%
Scale =[]
for i in range(len(scale)):
  Scale.append(scale[i])
Scale
# Out:
# [0.37906061016907133,
#  35.65466164189856,
#  0.30005879105679634,
#  1.7457795268546157,
#  3.5421005715124116,
#  0.1643291670691144,
#  0.41373173132806706,
#  0.49981220585159025,
#  0.8302196682690106,
#  31.79120723623166,
#  801.9469071814231,
#  1.1729106640540556,
#  0.04554865343078305,
#  0.4966987535086603,
#  73458.49780218955]

# %%
x_train_c,x_test_c,y_train_c,y_test_c=train_test_split(x,y_c,test_size=0.2, random_state=0)

# %%
pip install catboost

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from xgboost import XGBClassifier
from catboost import CatBoostClassifier
model1=GaussianNB()
model1.fit(x_train_c,y_train_c)
model2=QuadraticDiscriminantAnalysis()
model2.fit(x_train_c,y_train_c)
model3=XGBClassifier(random_state=0)
model3.fit(x_train_c,y_train_c)
model4=CatBoostClassifier(random_state=0)
model4.fit(x_train_c,y_train_c)
# Out:
# Learning rate set to 0.040999
# 0:	learn: 0.5742892	total: 88.6ms	remaining: 1m 28s
# 1:	learn: 0.4850953	total: 109ms	remaining: 54.3s
# 2:	learn: 0.4055586	total: 132ms	remaining: 43.8s
# 3:	learn: 0.3311823	total: 154ms	remaining: 38.4s
# 4:	learn: 0.2661202	total: 176ms	remaining: 35.1s
# 5:	learn: 0.2119735	total: 202ms	remaining: 33.4s
# 6:	learn: 0.1773171	total: 223ms	remaining: 31.6s
# 7:	learn: 0.1474667	total: 248ms	remaining: 30.7s
# 8:	learn: 0.1235736	total: 257ms	remaining: 28.3s
# 9:	learn: 0.1042106	total: 267ms	remaining: 26.4s
# 10:	learn: 0.0876923	total: 280ms	remaining: 25.2s
# 11:	learn: 0.0768782	total: 290ms	remaining: 23.9s
# 12:	learn: 0.0680288	total: 300ms	remaining: 22.8s
# 13:	learn: 0.0592241	total: 310ms	remaining: 21.8s
# 14:	learn: 0.0524672	total: 341ms	remaining: 22.4s
# 15:	learn: 0.0472204	total: 364ms	remaining: 22.4s
# 16:	learn: 0.0426883	total: 391ms	remaining: 22.6s
# 17:	learn: 0.0390245	total: 418ms	remaining: 22.8s
# ...

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
o1=model1.predict(x_test_c)
o2=model2.predict(x_test_c)
o3=model3.predict(x_test_c)
o4=model4.predict(x_test_c)
print('accuracy',accuracy_score(o1,y_test_c))
print('precision',precision_score(o1,y_test_c,average='micro'))
print('recall',recall_score(o1,y_test_c,average='micro'))
print('f1',f1_score(o1,y_test_c,average='micro'))
# Out:
# accuracy 0.9807874015748032
# precision 0.9807874015748032
# recall 0.9807874015748032
# f1 0.9807874015748032

# %%
print('accuracy',accuracy_score(o2,y_test_c))
print('precision',precision_score(o2,y_test_c,average='micro'))
print('recall',recall_score(o2,y_test_c,average='micro'))
print('f1',f1_score(o2,y_test_c,average='micro'))
# Out:
# accuracy 0.978740157480315
# precision 0.978740157480315
# recall 0.978740157480315
# f1 0.978740157480315

# %%
print('accuracy',accuracy_score(o3,y_test_c))
print('precision',precision_score(o3,y_test_c,average='micro'))
print('recall',recall_score(o3,y_test_c,average='micro'))
print('f1',f1_score(o3,y_test_c,average='micro'))
# Out:
# accuracy 0.9981102362204725
# precision 0.9981102362204725
# recall 0.9981102362204725
# f1 0.9981102362204725

# %%
print('accuracy',accuracy_score(o4,y_test_c))
print('precision',precision_score(o4,y_test_c,average='micro'))
print('recall',recall_score(o4,y_test_c,average='micro'))
print('f1',f1_score(o4,y_test_c,average='micro'))
# Out:
# accuracy 0.998740157480315
# precision 0.998740157480315
# recall 0.998740157480315
# f1 0.998740157480315

# %%
y_pred_prob = model3.predict_proba(x_test_c)[:, 1]

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test_c, o3)
class_labels = ['Class 0', 'Class 1']

cmap = sns.diverging_palette(10, 150, s=90, l=60, center='light', as_cmap=True)

plt.figure(figsize=(8, 6))
sns.set(font_scale=1.2)
sns.heatmap(cm, annot=True, cmap=cmap, fmt='d', xticklabels=class_labels, yticklabels=class_labels)

plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')

plt.show()

# %%
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test_c, y_pred_prob)

roc_auc = roc_auc_score(y_test_c, y_pred_prob)

# Plot the ROC curve
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='darkorange', lw=2, label=f'ROC curve (AUC = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
plt.xlim([-0.0025, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import make_classification
from sklearn.model_selection import learning_curve
from sklearn.tree import DecisionTreeClassifier

# Create learning curve
train_sizes, train_scores, test_scores = learning_curve(model3, x, y_c)

# Calculate mean and standard deviation for train and test scores
train_scores_mean = train_scores.mean(axis=1)
train_scores_std = train_scores.std(axis=1)
test_scores_mean = test_scores.mean(axis=1)
test_scores_std = test_scores.std(axis=1)

# Plot learning curve
plt.figure()
plt.title("Learning Curve")
plt.xlabel("Training examples")
plt.ylabel("Score")

# Plot the mean train and test scores
plt.plot(train_sizes, train_scores_mean, 'o-', color="r", label="Training score")
plt.plot(train_sizes, test_scores_mean, 'o-', color="g", label="Cross-validation score")

# Plot the standard deviations as shading
plt.fill_between(train_sizes, train_scores_mean - train_scores_std,
                 train_scores_mean + train_scores_std, alpha=0.1, color="r")
plt.fill_between(train_sizes, test_scores_mean - test_scores_std,
                 test_scores_mean + test_scores_std, alpha=0.1, color="g")

# Add a legend
plt.legend(loc="best")

plt.show()

# %%
from sklearn.metrics import precision_recall_curve, auc

precision, recall, thresholds = precision_recall_curve(y_test_c, y_pred_prob)

# Compute area under the curve (AUC) for precision-recall curve
auc_score = auc(recall, precision)

# Plot Precision-Recall curve
plt.figure()
plt.plot(recall, precision, color='blue', label=f'Precision-Recall curve (AUC = {auc_score:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc='best')
plt.show()
